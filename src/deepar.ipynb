# %%
import pandas as pd
pd.options.display.float_format = "{:.3f}".format

# %%
df = pd.read_csv("../results/traffic.csv")

# %%
df
# Out:
#             MSE    abs_error  abs_target_sum  abs_target_mean  seasonal_error  \
# 0 336863623.573 24230643.020   166958474.898        19007.112        1542.987
# 1  54041445.934 15448937.635   166958474.898        19007.112        1542.987
# 2 211358823.280 22100819.819   166958474.898        19007.112        1542.987
# 3 130043054.876 18184948.283   166958474.898        19007.112        1542.987
# 4  92829889.760 17102218.946   166958474.898        19007.112        1542.987
#
#    MASE  MAPE  sMAPE   MSIS  QuantileLoss[0.1]  ...      RMSE  NRMSE    ND  \
# 0 1.495 0.221  0.187 10.960        9603914.474  ... 18353.845  0.966 0.145
# 1 1.414 0.206  0.182 10.600        6920600.677  ...  7351.289  0.387 0.093
# 2 1.445 0.215  0.183 10.827       10015881.511  ... 14538.185  0.765 0.132
# 3 1.393 0.207  0.180 10.734        8216895.743  ... 11403.642  0.600 0.109
# 4 1.413 0.208  0.180 10.760        6792375.976  ...  9634.827  0.507 0.102
#
# ...

# %%
df.mean()
# Out:
# MSE                          165027367.485
# abs_error                     19413513.541
# abs_target_sum               166958474.898
# abs_target_mean                  19007.112
# seasonal_error                    1542.987
# MASE                                 1.432
# MAPE                                 0.211
# sMAPE                                0.183
# MSIS                                10.776
# QuantileLoss[0.1]              8309933.676
# Coverage[0.1]                        0.083
# QuantileLoss[0.5]             19413513.470
# Coverage[0.5]                        0.534
# QuantileLoss[0.9]              9695135.559
# Coverage[0.9]                        0.914
# RMSE                             12256.358
# NRMSE                                0.645
# ND                                   0.116
# wQuantileLoss[0.1]                   0.050
# wQuantileLoss[0.5]                   0.116
# wQuantileLoss[0.9]                   0.058
# mean_absolute_QuantileLoss    12472860.902
# ...
